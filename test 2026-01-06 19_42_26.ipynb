# %%
df=spark.read.json("/Volumes/workspace/dev/dev_test/stores_test/stores_test/stores_mumbai.json")

# %%
df1=spark.read.json("/Volumes/workspace/dev/dev_test/stores_test/stores_test/stores_tokyo.json")
df1.printSchema()

# %%
df_union=df.union(df1)
df_union.show()
df_union.count()

# %%
df_union.write.format('delta').mode('overwrite').saveAsTable("dev.Stores")
